# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
file_path = "chipotle.tsv"

chipo = pd.read_csv(file_path, sep="\t")

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo["item_price"] = chipo["item_price"].apply(lambda price: float(price[1:]))
chipo[chipo["item_price"] > 10].shape[0]
# Out:
# 1130

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
chipo["product_price"] = chipo["item_price"] / chipo["quantity"]

# %%
chipo[["item_name", "choice_description", "product_price"]].drop_duplicates().sort_values(by="item_name")
# Out:
#               item_name                                 choice_description  \
# 357   6 Pack Soft Drink                                             [Coke]
# 3141  6 Pack Soft Drink                                         [Lemonade]
# 721   6 Pack Soft Drink                                           [Nestea]
# 298   6 Pack Soft Drink                                           [Sprite]
# 341   6 Pack Soft Drink                                        [Diet Coke]
# ...                 ...                                                ...
# 781   Veggie Soft Tacos  [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...
# 2851  Veggie Soft Tacos  [Roasted Chili Corn Salsa (Medium), [Black Bea...
# 1395  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...
# 3889  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# 1699  Veggie Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
#
#       product_price
# 357            6.49
# 3141           6.49
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by="item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by="item_price", ascending=False).head(1)[["item_name", "quantity", "item_price"]]
# Out:
#                          item_name  quantity  item_price
# 3598  Chips and Fresh Tomato Salsa        15       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
veggie_salad_bowl = chipo[chipo["item_name"] == "Veggie Salad Bowl"]
veggie_salad_bowl["quantity"].sum()
# Out:
# np.int64(18)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
canned_soda = chipo[chipo["item_name"] == "Canned Soda"]
canned_soda[canned_soda["quantity"] > 1].shape[0]
# Out:
# 20
